# %%
from janome.tokenizer import Tokenizer
text = "コンピュータは、電子計算機を指し、電子回路による、デジタル方式でなおかつプログラム内蔵方式のコンピュータを指す。さまざまな演算を高速・大量に行うことが可能である。用途は多様で、数値計算、情報処理、データ処理、制御、シミュレーション、文書作成、動画編集、ゲームなどに用いられている。"
t = Tokenizer()
for token in t.tokenize(text):
    print(token)
# Out:
# コンピュータ	名詞,一般,*,*,*,*,コンピュータ,コンピュータ,コンピュータ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# 電子	名詞,一般,*,*,*,*,電子,デンシ,デンシ
# 計算	名詞,サ変接続,*,*,*,*,計算,ケイサン,ケイサン
# 機	名詞,接尾,一般,*,*,*,機,キ,キ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 指し	動詞,自立,*,*,五段・サ行,連用形,指す,サシ,サシ
# 、	記号,読点,*,*,*,*,、,、,、
# 電子	名詞,一般,*,*,*,*,電子,デンシ,デンシ
# 回路	名詞,一般,*,*,*,*,回路,カイロ,カイロ
# による	助詞,格助詞,連語,*,*,*,による,ニヨル,ニヨル
# 、	記号,読点,*,*,*,*,、,、,、
# デジタル	名詞,一般,*,*,*,*,デジタル,デジタル,デジタル
# 方式	名詞,一般,*,*,*,*,方式,ホウシキ,ホーシキ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# なおかつ	副詞,一般,*,*,*,*,なおかつ,ナオカツ,ナオカツ
# プログラム	名詞,サ変接続,*,*,*,*,プログラム,プログラム,プログラム
# 内蔵	名詞,サ変接続,*,*,*,*,内蔵,ナイゾウ,ナイゾー
# 方式	名詞,一般,*,*,*,*,方式,ホウシキ,ホーシキ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# コンピュータ	名詞,一般,*,*,*,*,コンピュータ,コンピュータ,コンピュータ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 指す	動詞,自立,*,*,五段・サ行,基本形,指す,サス,サス
# 。	記号,句点,*,*,*,*,。,。,。
# さまざま	名詞,形容動詞語幹,*,*,*,*,さまざま,サマザマ,サマザマ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 演算	名詞,サ変接続,*,*,*,*,演算,エンザン,エンザン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 高速	名詞,一般,*,*,*,*,高速,コウソク,コーソク
# ・	記号,一般,*,*,*,*,・,・,・
# 大量	名詞,形容動詞語幹,*,*,*,*,大量,タイリョウ,タイリョー
# ...
